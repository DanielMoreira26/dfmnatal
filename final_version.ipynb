# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielMoreira26/dfmnatal/blob/main/final_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dados das análises
dados = {
    'cloro_residual': {
        'leste': {'aprovado': 56, 'reprovado': 16},
        'oeste': {'aprovado': 42, 'reprovado': 10},
        'norte1': {'aprovado': 32, 'reprovado': 5},
        'norte2': {'aprovado': 26, 'reprovado': 8},
        'sul': {'aprovado': 80, 'reprovado': 25}
    },
    'turbidez': {
        'leste': {'aprovado': 56, 'reprovado': 4},
        'oeste': {'aprovado': 42, 'reprovado': 5},
        'norte1': {'aprovado': 32, 'reprovado': 3},
        'norte2': {'aprovado': 26, 'reprovado': 7},
        'sul': {'aprovado': 80, 'reprovado': 15}
    },
    'cor_aparente': {
        'leste': {'aprovado': 56, 'reprovado': 3},
        'oeste': {'aprovado': 42, 'reprovado': 1},
        'norte1': {'aprovado': 32, 'reprovado': 5},
        'norte2': {'aprovado': 26, 'reprovado': 11},
        'sul': {'aprovado': 80, 'reprovado': 1}
    },
    'escherichia_coli': {
        'leste': {'aprovado': 56, 'reprovado': 0},
        'oeste': {'aprovado': 42, 'reprovado': 1},
        'norte1': {'aprovado': 32, 'reprovado': 0},
        'norte2': {'aprovado': 26, 'reprovado': 0},
        'sul': {'aprovado': 80, 'reprovado': 0}
    },
    'pH': {
        'leste': {'aprovado': 56, 'reprovado': 26},
        'oeste': {'aprovado': 42, 'reprovado': 19},
        'norte1': {'aprovado': 32, 'reprovado': 9},
        'norte2': {'aprovado': 26, 'reprovado': 5},
        'sul': {'aprovado': 80, 'reprovado': 40}
    },
    'coliformes_totais': {
        'leste': {'aprovado': 56, 'reprovado': 7},
        'oeste': {'aprovado': 42, 'reprovado': 2},
        'norte1': {'aprovado': 32, 'reprovado': 6},
        'norte2': {'aprovado': 26, 'reprovado': 13},
        'sul': {'aprovado': 80, 'reprovado': 4}
    }
}

# Informações dos parâmetros
parametros = {
    1: "Cloro Residual (0.2, 2.0) mg/L",
    2: "pH (6.5, 8.5)",
    3: "Turbidez (0.0, 5.0 NTU)",
    4: "Cor Aparente (0.0, 15 UH)",
    5: "Coliformes Totais (0, 0), UFC/100mL",
    6: "Escherichia Coli (0, 0), UFC/100mL"
}

def exibir_dados_parametro(parametro):
    """
    Exibe os dados de um parâmetro específico para todas as regiões.
    """
    parametro_chave = list(parametros.keys())[parametro - 1]
    parametro_nome = list(parametros.values())[parametro - 1]
    parametro_chave_str = list(dados.keys())[parametro_chave - 1]

    print(f"Dados para o parâmetro '{parametro_nome}':")
    if parametro_chave_str in dados:
        total_aprovados = 0
        total_reprovados = 0
        for regiao, resultados in dados[parametro_chave_str].items():
            aprovados = resultados['aprovado']
            reprovados = resultados['reprovado']
            total_aprovados += aprovados
            total_reprovados += reprovados
            print(f"{regiao.capitalize()}: Aprovados - {aprovados}, Reprovados - {reprovados}")

        total_amostras = total_aprovados + total_reprovados
        percentual_reprovadas = (total_reprovados / total_amostras) * 100

        # Avaliação da qualidade da água
        if percentual_reprovadas <= 3:
            qualidade_agua = "Boa"
        elif percentual_reprovadas <= 5:
            qualidade_agua = "Regular"
        else:
            qualidade_agua = "Ruim"

        print(f"Total de amostras aprovadas: {total_aprovados}")
        print(f"Total de amostras reprovadas: {total_reprovados}")
        print(f"Percentual de amostras reprovadas: {percentual_reprovadas:.2f}%")
        print(f"A qualidade da água é considerada: {qualidade_agua}\n")
    else:
        print(f"Dados para o parâmetro {parametro_chave_str} não encontrados.")

# Função principal para interação com o usuário
def main():
    while True:
        codigo = int(input("Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: "))
        if codigo == 0:
            print("Programa finalizado.")
            break
        elif codigo in parametros:
            exibir_dados_parametro(codigo)
        else:
            print("Código inválido. Por favor, tente novamente.")

if __name__ == "__main__":
    main()
# Out:
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 7
# Código inválido. Por favor, tente novamente.
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 6
# Dados para o parâmetro 'Escherichia Coli (0, 0), UFC/100mL':
# Leste: Aprovados - 56, Reprovados - 7
# Oeste: Aprovados - 42, Reprovados - 2
# Norte1: Aprovados - 32, Reprovados - 6
# Norte2: Aprovados - 26, Reprovados - 13
# Sul: Aprovados - 80, Reprovados - 4
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 32
# Percentual de amostras reprovadas: 11.94%
# A qualidade da água é considerada: Ruim
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 5
# Dados para o parâmetro 'Coliformes Totais (0, 0), UFC/100mL':
# Leste: Aprovados - 56, Reprovados - 26
# Oeste: Aprovados - 42, Reprovados - 19
# Norte1: Aprovados - 32, Reprovados - 9
# Norte2: Aprovados - 26, Reprovados - 5
# Sul: Aprovados - 80, Reprovados - 40
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 99
# Percentual de amostras reprovadas: 29.55%
# A qualidade da água é considerada: Ruim
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 4
# Dados para o parâmetro 'Cor Aparente (0.0, 15 UH)':
# Leste: Aprovados - 56, Reprovados - 0
# Oeste: Aprovados - 42, Reprovados - 1
# Norte1: Aprovados - 32, Reprovados - 0
# Norte2: Aprovados - 26, Reprovados - 0
# Sul: Aprovados - 80, Reprovados - 0
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 1
# Percentual de amostras reprovadas: 0.42%
# A qualidade da água é considerada: Boa
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 3
# Dados para o parâmetro 'Turbidez (0.0, 5.0 NTU)':
# Leste: Aprovados - 56, Reprovados - 3
# Oeste: Aprovados - 42, Reprovados - 1
# Norte1: Aprovados - 32, Reprovados - 5
# Norte2: Aprovados - 26, Reprovados - 11
# Sul: Aprovados - 80, Reprovados - 1
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 21
# Percentual de amostras reprovadas: 8.17%
# A qualidade da água é considerada: Ruim
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 2
# Dados para o parâmetro 'pH (6.5, 8.5)':
# Leste: Aprovados - 56, Reprovados - 4
# Oeste: Aprovados - 42, Reprovados - 5
# Norte1: Aprovados - 32, Reprovados - 3
# Norte2: Aprovados - 26, Reprovados - 7
# Sul: Aprovados - 80, Reprovados - 15
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 34
# Percentual de amostras reprovadas: 12.59%
# A qualidade da água é considerada: Ruim
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 1
# Dados para o parâmetro 'Cloro Residual (0.2, 2.0) mg/L':
# Leste: Aprovados - 56, Reprovados - 16
# Oeste: Aprovados - 42, Reprovados - 10
# Norte1: Aprovados - 32, Reprovados - 5
# Norte2: Aprovados - 26, Reprovados - 8
# Sul: Aprovados - 80, Reprovados - 25
# Total de amostras aprovadas: 236
# Total de amostras reprovadas: 64
# Percentual de amostras reprovadas: 21.33%
# A qualidade da água é considerada: Ruim
#
# Digite o código do parâmetro (1-6) para ver detalhes ou 0 para sair: 0
# Programa finalizado.
